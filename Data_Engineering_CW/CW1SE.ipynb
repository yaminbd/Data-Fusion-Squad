# %%
import requests
import psycopg2
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.amazon.co.uk/s?k=data+engeering&rh=n%3A404028&ref=nb_sb_noss"


HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36' })
response = requests.get(url, headers=HEADERS)

response
# Out:
# <Response [200]>

# %%
def creat_database():
    conn= psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=123456")
    conn.set_session(autocommit=True)
    cur=conn.cursor()

    cur.execute("DROP DATABASE IF EXISTS accounts")
    cur.execute("CREATE DATABASE accounts")

    conn.close()

    conn= psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=123456")
    cur=conn.cursor()

    return cur, conn

# %%
file_path = r'C:\Users\yamin\OneDrive - University of Roehampton\Data Engineering\Data_Engineering_CW\Book1.csv'



# Read the CSV file into a DataFrame with the appropriate encoding
Books = pd.read_csv(file_path, encoding='latin1')
# Display the first few rows of the DataFrame
Books.head()
# Out:
#                                             Title           Author       Date  \
# 0                       Data Engineering with dbt    Marcelo Leite  25-Nov-22
# 1         Mastering Databricks Lakehouse Platform        Sagar Lad  11-Jul-22
# 2                        Data Engineering with db    Roberto Zagni  30-Jun-23
# 3     Data Engineering with Google Cloud Platform       Adi Wijaya  31-Mar-22
# 4  The Definitive Guide to Azure Data Engineering  Ron C. L'Esteve  07-Aug-21
#
#     Price              Rating
# 0  £33.99  3.9 out of 5 stars
# 1  £24.99  3.5 out of 5 stars
# 2  £37.99  4.7 out of 5 stars
# 3  £39.99  4.6 out of 5 stars
# 4  £39.99  4.1 out of 5 stars

# %%
def drop_tables(cur, conn):
    for query in drop_table_queries:
        cur.excute(query)
        conn.commit()

# %%
def creat_tables(cur,conn):
    for query in create_table_queries:
         cur.excute(query)
         conn.commit()

# %%
cur, conn = creat_database()

Books = ("CREATE TABLE IF NOT EXISTS booksData(Title VARCHAR, Author VARCHAR, Date DATE, Price MONEY, Rating VARCHAR);")

cur.execute(Books)
conn.commit()

# %%
# Specify the file path
file_path = r'C:\Users\yamin\OneDrive - University of Roehampton\Data Engineering\Data_Engineering_CW\Book1.csv'
# Read the CSV file into a DataFrame with the appropriate encoding
Books = pd.read_csv(file_path, encoding='latin1')


# Display the first few rows of the DataFrame
Books.head()
# Assuming 'Books' is your DataFrame containing the data
Books = Books[['Title', 'Author', 'Date', 'Price', 'Rating']]

# %%
Books.head()
# Out:
#                                             Title           Author       Date  \
# 0                       Data Engineering with dbt    Marcelo Leite  25-Nov-22
# 1         Mastering Databricks Lakehouse Platform        Sagar Lad  11-Jul-22
# 2                        Data Engineering with db    Roberto Zagni  30-Jun-23
# 3     Data Engineering with Google Cloud Platform       Adi Wijaya  31-Mar-22
# 4  The Definitive Guide to Azure Data Engineering  Ron C. L'Esteve  07-Aug-21
#
#     Price              Rating
# 0  £33.99  3.9 out of 5 stars
# 1  £24.99  3.5 out of 5 stars
# 2  £37.99  4.7 out of 5 stars
# 3  £39.99  4.6 out of 5 stars
# 4  £39.99  4.1 out of 5 stars

# %%
books_insert = ("""INSERT INTO Books (Title, Author, Date, Price, Rating) VALUES (%s, %s, %s, %s, %s)""")

# %%
# Create a cursor object
cur = conn.cursor()

# Define the insertion query
books_insert = """
    INSERT INTO Books (Title, Author, Date, Price, Rating) 
    VALUES (%s, %s, %s, %s, %s)
"""

# Specify the file path
file_path = r'C:\Users\yamin\OneDrive - University of Roehampton\Data Engineering\Data_Engineering_CW\books.csv'

# Read the CSV file into a DataFrame
Books = pd.read_csv(file_path)

try:
    # Rollback the current transaction
    conn.rollback()

    # Iterate over the DataFrame rows and execute insert statements
    for index, row in Books.iterrows():
        cur.execute(books_insert, (row['Title'], row['Author'], row['Date'], row['Price'], row['Rating']))

    # Commit the transaction
    conn.commit()

except Exception as e:
    # If an exception occurs, print the error message and rollback the transaction
    print("An error occurred:", e)
    conn.rollback()

finally:
    # Close the cursor and connection
    cur.close()
    conn.close()
# Out:
# An error occurred: relation "books" does not exist
# LINE 2:     INSERT INTO Books (Title, Author, Date, Price, Rating)
#                         ^

# %%
# Establish a connection to the PostgreSQL database
conn = psycopg2.connect(
    host="127.0.0.1",
    dbname="postgres",
    user="postgres",
    password="123456"
)


# Create a cursor object
cur = conn.cursor()

# Define the insertion query
books_insert = """
    INSERT INTO Books (Title, Author, Date, Price, Rating) 
    VALUES (%s, %s, %s, %s, %s)
"""

# Define the table creation query
create_table_query = """
    CREATE TABLE IF NOT EXISTS Books (
        Title VARCHAR,
        Author VARCHAR,
        Date DATE,
        Price MONEY,
        Rating VARCHAR
    )
"""

# Execute the table creation query
cur.execute(create_table_query)

# Commit the transaction
conn.commit()

# Specify the file path
file_path = r'C:\Users\yamin\OneDrive - University of Roehampton\Data Engineering\Data_Engineering_CW\Book1.csv'

# Read the CSV file into a DataFrame with the appropriate encoding
Books = pd.read_csv(file_path, encoding='latin1')

try:
    # Rollback the current transaction
    conn.rollback()

    # Iterate over the DataFrame rows and execute insert statements
    for index, row in Books.iterrows():
        cur.execute(books_insert, (row['Title'], row['Author'], row['Date'], row['Price'], row['Rating']))

    # Commit the transaction
    conn.commit()

except Exception as e:
    # If an exception occurs, print the error message and rollback the transaction
    print("An error occurred:", e)
    conn.rollback()

finally:
    # Close the cursor and connection
    cur.close()
    conn.close()

# %%
conn.commit()

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-gb"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
div = soup.find('div')

# %%
# Assuming soup is your BeautifulSoup object for the whole page
articles = soup.find_all('a', class_='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal')

for article in articles:
    title = article.get_text().strip()  # Extracting text content of the link
    by = article.get_text().strip()
    print(title)
    print(by)
# Out:
# Microsoft Certified Azure Data Fundamentals (Exam DP-900) Certification Guide: The comprehensive guide to passing the DP-900 exam on your first attempt
# Microsoft Certified Azure Data Fundamentals (Exam DP-900) Certification Guide: The comprehensive guide to passing the DP-900 exam on your first attempt
# Mastering Databricks Lakehouse Platform: Perform Data Warehousing, Data Engineering, Machine Learning, DevOps, and BI into a Single Platform (English Edition)
# Mastering Databricks Lakehouse Platform: Perform Data Warehousing, Data Engineering, Machine Learning, DevOps, and BI into a Single Platform (English Edition)
# Data Engineering with dbt: A practical guide to building a cloud-based, pragmatic, and dependable data platform with SQL
# Data Engineering with dbt: A practical guide to building a cloud-based, pragmatic, and dependable data platform with SQL
# Data Engineering with Google Cloud Platform: A practical guide to operationalizing scalable data analytics systems on GCP
# ...

# %%
# Assuming soup is your BeautifulSoup object for the whole page
articles = soup.find_all('span', class_='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal')

for span in articles:
    by = article.get_text().strip()  # Extracting text content of the link
    print(by)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.amazon.co.uk/s?k=data+engeering&rh=n%3A404028&ref=nb_sb_noss'
HEADERS = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'}

response = requests.get(url, headers=HEADERS)
soup = BeautifulSoup(response.content, 'html.parser')

book_containers = soup.find_all('div', class_='s-asin')  # Each book container

for book in book_containers:
    # Extract title
    title = book.find('span', class_='a-size-medium').get_text().strip() if book.find('span', class_='a-size-medium') else 'No Title Found'
    
    author = book.find('a', class_="a-size-base a-link-normal s-underline-text s-underline-link-text s-link-style").get_text().strip() if book.find('a', class_="a-size-base a-link-normal s-underline-text s-underline-link-text s-link-style") else 'No Author Found'
    
    date = book.find('span', class_='a-size-base a-color-secondary a-text-normal').get_text().strip() if book.find('span', class_='a-size-base a-color-secondary a-text-normal') else 'No Date Found'
    
    price_container = book.find('span', class_='a-price')  # Assuming this is the container for the price
    if price_container:
       price_span = price_container.find('span', class_='a-offscreen')  # Often used for the actual price
       price = price_span.get_text().strip() if price_span else 'No Price Found'
    else:
       price = 'No Price Found'

    rating_tag = book.find('i', {'class': 'a-icon-star-small'})
    rating_text = 'No Rating Found'  # Default text if rating is not found
    if rating_tag:
        rating_span = rating_tag.find('span', {'class': 'a-icon-alt'})
        if rating_span:
            rating_text = rating_span.get_text().strip()
    print(f"Title: {title}\nAuthor: {author}\nDate: {date}\nPrice: {price}\nRating: {rating_text}\n---")
# Out:
# Title: Microsoft Certified Azure Data Fundamentals (Exam DP-900) Certification Guide: The comprehensive guide to passing the DP-900 exam on your first attempt
# Author: Marcelo Leite
# Date: 25 Nov 2022
# Price: £33.99
# Rating: 3.9 out of 5 stars
# ---
# Title: Mastering Databricks Lakehouse Platform: Perform Data Warehousing, Data Engineering, Machine Learning, DevOps, and BI into a Single Platform (English Edition)
# Author: Sagar Lad
# Date: 11 Jul 2022
# Price: £24.99
# Rating: 3.5 out of 5 stars
# ---
# Title: Data Engineering with dbt: A practical guide to building a cloud-based, pragmatic, and dependable data platform with SQL
# Author: Roberto Zagni
# Date: 30 Jun 2023
# Price: £37.99
# Rating: 4.7 out of 5 stars
# ---
# Title: Data Engineering with Google Cloud Platform: A practical guide to operationalizing scalable data analytics systems on GCP
# Author: Adi Wijaya
# Date: 31 Mar 2022
# Price: £39.99
# Rating: 4.6 out of 5 stars
# ---
# ...

# %%
books = []
for i in range(1, 75):
    url = "https://www.amazon.co.uk/s?k=data+engeering&rh=n%3A404028&ref=nb_sb_noss"
    HEADERS = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'}

    response = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(response.content, 'html.parser')

    book_containers = soup.find_all('div', class_='s-asin')
    
    for book in book_containers:
        title = book.find('span', class_='a-size-medium').get_text().strip() if book.find('span', class_='a-size-medium') else 'No Title Found'
    
        author = book.find('a', class_="a-size-base a-link-normal s-underline-text s-underline-link-text s-link-style").get_text().strip() if book.find('a', class_="a-size-base a-link-normal s-underline-text s-underline-link-text s-link-style") else 'No Author Found'
    
        date = book.find('span', class_='a-size-base a-color-secondary a-text-normal').get_text().strip() if book.find('span', class_='a-size-base a-color-secondary a-text-normal') else 'No Date Found'
    
        price_container = book.find('span', class_='a-price') 
        if price_container:
            price_span = price_container.find('span', class_='a-offscreen')  
            price = price_span.get_text().strip() if price_span else 'No Price Found'
        else:
            price = 'No Price Found'

        # Extract rating
        rating_tag = book.find('i', {'class': 'a-icon-star-small'})
        rating_text = 'No Rating Found'  # Default text if rating is not found
        if rating_tag:
            rating_span = rating_tag.find('span', {'class': 'a-icon-alt'})
            if rating_span:
                rating_text = rating_span.get_text().strip()

        books.append((title, author, date, price, rating_text))

# %%
df = pd.DataFrame(books,columns = ['Title', 'Author', '','Price','Star Rating'])

# %%
df.to_csv('books.csv')
